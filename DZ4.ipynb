# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x = []   
y1 = []
y2 = []
y3 = []

m = 1000    # масштаб
for i in np.arange(0.01, 0.020, 0.0001):
    x_ = i
    x.append(x_)
    y1.append(np.pi/i)
    y2.append(2 * np.pi/i) 
    y3.append(3 * np.pi/i) 
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.xlabel("a")
plt.ylabel("x")
x = [0.01, 0.01, 0.02, 0.02, 0.01]
y = [100, 500, 500, 100, 100]
plt.plot(x, y, '--r')
